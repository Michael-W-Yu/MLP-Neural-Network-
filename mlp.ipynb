# %% [markdown]
# **Seungjae Lee and Michael Yu**
#
# Fall 2019
#
# CS 343: Neural Networks
#
# Project 2: Multi-layer Perceptrons
#
# **Draft due 11:59pm Thurs Sept 26**
#
#
# Summary of files in this project:
# - `softmax_layer.ipynb`
# - `single_layer_net.py`
# - `preprocess_data.py`
# - `mlp.ipynb`
# - `mlp.py`
#
# **REMINDER**: Submit rubric on Google Classroom

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# for obtaining the STL-dataset
import load_stl10_dataset

# for preprocessing dataset
import preprocess_data

# Set the color style so that Professor Layton can see your plots
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])
# Make the font size larger
plt.rcParams.update({'font.size': 20})

# Turn off scientific notation when printing
np.set_printoptions(suppress=True, precision=3)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data
#
# ### a. STL-10
#
# **TODO**: Run the cell below, to preprocess STL-10 dataset like you did in the other notebook.

# %%
# Download the dataset from the internet, convert it to Numpy ndarray, resize to 32x32
# cache it locally on your computer for faster loading next time.
stl_imgs, stl_labels = load_stl10_dataset.load()

# Load in the string names for each class
classes = np.loadtxt(os.path.join('data', 'stl10_binary', 'class_names.txt'), dtype=str)

# Preprocess image pixel values for the MLP net
stl_imgs, stl_labels = preprocess_data.preprocess_stl(stl_imgs, stl_labels)
print(f'stl_imgs dtype is {stl_imgs.dtype} and it should be float64')
print(f'stl_imgs max is {np.max(stl_imgs[:, 1:]):.3f} and it should be 0.668')
print(f'stl_imgs shape is {stl_imgs.shape} and it should be (5000, 3072)')
print(f'stl_labels span {stl_labels.min()}->{stl_labels.max()} and it should be 0->9')
    
x_train, y_train, x_test, y_test, x_val, y_val, x_dev, y_dev = preprocess_data.create_splits(stl_imgs, stl_labels)  
print ('Train data shape: ', x_train.shape)
print ('Train labels shape: ', y_train.shape)
print ('Test data shape: ', x_test.shape)
print ('Test labels shape: ', y_test.shape)
print ('Validation data shape: ', x_val.shape)
print ('Validation labels shape: ', y_val.shape)
print ('dev data shape: ', x_dev.shape)
print ('dev labels shape: ', y_dev.shape)
# Out:
# Found cached numpy arrays the images and labels. Loading them...
# Images are: (5000, 32, 32, 3)
# Labels are: (5000,)
# stl_imgs dtype is float64 and it should be float64
# stl_imgs max is 0.668 and it should be 0.668
# stl_imgs shape is (5000, 3072) and it should be (5000, 3072)
# stl_labels span 0->9 and it should be 0->9
# Train data shape:  (3500, 3072)
# Train labels shape:  (3500,)
# Test data shape:  (500, 3072)
# Test labels shape:  (500,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)

# %% [markdown]
# ### Circle in a square
#
# **TODO** Run the code below from the other notebook to load in the CIS dataset

# %%
val_size = 20

cis_train_path = os.path.join('data', 'cis', 'cis_train.dat')
cis_test_path = os.path.join('data', 'cis', 'cis_test.dat')

cis_train_all = np.loadtxt(cis_train_path, delimiter='\t')

# shuffle the data
s_inds = np.arange(len(cis_train_all))
cis_train_all = cis_train_all[s_inds]

cis_train_x = cis_train_all[:, :2]
cis_train_y = cis_train_all[:, 2].astype(int)

cis_val_x = cis_train_x[:val_size]
cis_train_x = cis_train_x[val_size:]
cis_val_y = cis_train_y[:val_size]
cis_train_y = cis_train_y[val_size:]

cis_test_all = np.loadtxt(cis_test_path, delimiter='\t')
cis_test_x = cis_test_all[:, :2]
cis_test_y = cis_test_all[:, 2].astype(int)

print ('CIS Train data shape: ', cis_train_x.shape)
print ('CIS Train labels shape: ', cis_train_y.shape)
print ('CIS Validation data shape: ', cis_val_x.shape)
print ('CIS Validation labels shape: ', cis_val_y.shape)
print ('CIS Test data shape: ', cis_test_x.shape)
print ('CIS Test labels shape: ', cis_test_y.shape)
# Out:
# CIS Train data shape:  (80, 2)
# CIS Train labels shape:  (80,)
# CIS Validation data shape:  (20, 2)
# CIS Validation labels shape:  (20,)
# CIS Test data shape:  (10000, 2)
# CIS Test labels shape:  (10000,)

# %% [markdown]
# ### b. Circle in a square dataset
#
# **Properties:**
# - 2 classes of features
#
# **TODO**:
# 1. Download the circle in a square dataset. Folder structure is `<project folder>/data/cis/<cis dat files>`
# 2. Create numpy arrays for the train/test data and separate variables for the associated labels by running the below code

# %%
val_size = 20

cis_train_path = os.path.join('data', 'cis', 'cis_train.dat')
cis_test_path = os.path.join('data', 'cis', 'cis_test.dat')

cis_train_all = np.loadtxt(
cis_train_path, delimiter='\t')

cis_train_x = cis_train_all[:, :2]
cis_train_y = cis_train_all[:, 2].astype(int)

cis_val_x = cis_train_x[:val_size]
cis_train_x = cis_train_x[val_size:]
cis_val_y = cis_train_y[:val_size]
cis_train_y = cis_train_y[val_size:]

cis_test_all = np.loadtxt(cis_test_path, delimiter='\t')
cis_test_x = cis_test_all[:, :2]
cis_test_y = cis_test_all[:, 2].astype(int)

print ('CIS Train data shape: ', cis_train_x.shape)
print ('CIS Train labels shape: ', cis_train_y.shape)
print ('CIS Validation data shape: ', cis_val_x.shape)
print ('CIS Validation labels shape: ', cis_val_y.shape)
print ('CIS Test data shape: ', cis_test_x.shape)
print ('CIS Test labels shape: ', cis_test_y.shape)
# Out:
# CIS Train data shape:  (80, 2)
# CIS Train labels shape:  (80,)
# CIS Validation data shape:  (20, 2)
# CIS Validation labels shape:  (20,)
# CIS Test data shape:  (10000, 2)
# CIS Test labels shape:  (10000,)

# %% [markdown]
# Below, you should see a...black circle in a white unit square :)

# %%
plt.scatter(cis_test_x[:,0], cis_test_x[:,1], c=cis_test_y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Task 3) Implement Multilayer Perceptron (MLP) with softmax activation and cross-entropy loss
#
# Now that we've tested the softmax activation function and cross-entropy loss functions in a single-layer net, let's implement the MLP version.
#
# Much of your work on the single layer net will carry over, so go ahead and copy-paste and modify as needed!
#
# The structure of our MLP will be:
#
# Input layer (X units) -> Hidden layer (Y units) with Rectified Linear activation (ReLu) -> Output layer (Z units) with softmax activation

# %% [markdown]
# ### a. Implement the following functions in `mlp.py`
#
# - `initialize_wts`
# - `accuracy`
# - `one_hot`
# - `predict`
# - `forward`
# - `backward`
# - `fit`

# %% [markdown]
# ### b. Test key functions with randomly generated data

# %%
from mlp import MLP

# %%
# Create a dummy net for debugging
num_inputs = 3
num_features = 6
num_hidden_units = 7
num_classes = 5

net = MLP(num_features, num_hidden_units, num_classes)

# %%
# Generate random data and classes
np.random.seed(0)
test_x = np.random.normal(loc=0, scale=100, size=(num_inputs, num_features))
test_y = np.random.uniform(low=0, high=num_classes-1, size=(num_inputs,))
test_y = test_y.astype(int)
print(f'Test input shape: {test_x.shape}')
print(f'Test class vector shape: {test_y.shape}')
# Out:
# Test input shape: (3, 6)
# Test class vector shape: (3,)

# %% [markdown]
# Test `initialize_wts`

# %%
net.initialize_wts(M=num_features, H=num_hidden_units, C=num_classes, std=0.01)
print(f'y wt shape is {net.y_wts.shape} and should be (6, 7)')
print(f'y bias shape is {net.y_b.shape} and should be (7,)')
print(f'z wt shape is {net.z_wts.shape} and should be (7, 5)')
print(f'z bias shape is {net.z_b.shape} and should be (5,)')

print(f'1st few y wts are\n{net.y_wts[:,0]}\nand should be\n[ 0.018 -0.002  0.004  0.007  0.015  0.002]')
print(f'y bias is\n{net.y_b}\nand should be\n[-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]')
print(f'1st few z wts are\n{net.z_wts[:,0]}\nand should be\n[-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]')
print(f'z bias is\n{net.z_b}\nand should be\n[ 0.015  0.019  0.012 -0.002 -0.011]')
# Out:
# y wt shape is (6, 7) and should be (6, 7)
# y bias shape is (7,) and should be (7,)
# z wt shape is (7, 5) and should be (7, 5)
# z bias shape is (5,) and should be (5,)
# 1st few y wts are
# [ 0.018 -0.002  0.004  0.007  0.015  0.002]
# and should be
# [ 0.018 -0.002  0.004  0.007  0.015  0.002]
# y bias is
# [-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]
# and should be
# [-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]
# 1st few z wts are
# [-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]
# and should be
# [-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]
# z bias is
# [ 0.015  0.019  0.012 -0.002 -0.011]
# and should be
# [ 0.015  0.019  0.012 -0.002 -0.011]

# %% [markdown]
# Test the `predict` method

# %%
test_y_pred = net.predict(test_x)
print(f'Predicted classes are {test_y_pred} and should be [3 0 0]')
# Out:
# Predicted classes are [3 0 0] and should be [3 0 0]

# %% [markdown]
# Test the `forward` method focusing on`ReLU`(net act of hidden layer `y`)

# %%
_,y_net_act_test,_,_,_ = net.forward(test_x, test_y)

correct_y_act = np.array([[7.66 , 4.47 , 0.804, 9.981, 0.   , 0.   , 0.   ],
       [2.37 , 2.717, 2.18 , 2.552, 0.357, 0.   , 0.   ],
       [3.997, 2.671, 1.195, 3.034, 0.   , 0.   , 0.   ]])

print(f'Your y activation is\n{y_net_act_test}')
print(f'The correct y activation (ReLU) is\n{y_net_act_test}')
# Out:
# Your y activation is
# [[7.643 4.49  0.799 9.977 0.    0.    0.   ]
#  [2.353 2.737 2.175 2.547 0.345 0.    0.   ]
#  [3.98  2.691 1.19  3.029 0.    0.    0.   ]]
# The correct y activation (ReLU) is
# [[7.643 4.49  0.799 9.977 0.    0.    0.   ]
#  [2.353 2.737 2.175 2.547 0.345 0.    0.   ]
#  [3.98  2.691 1.19  3.029 0.    0.    0.   ]]

# %% [markdown]
# Test the `forward` method

# %%
_,_,_,probs,_ = net.forward(test_x, test_y)

correct_probs = np.array([[0.219, 0.2  , 0.191, 0.219, 0.171],
       [0.208, 0.204, 0.201, 0.205, 0.183],
       [0.208, 0.202, 0.202, 0.205, 0.183]])

print(f'Your z activation (class probabilities) is\n{probs}')
print(f'The correct z activation (class probabilities) is\n{correct_probs}')
print(f'The sums across rows (for each data sample) are {np.sum(probs, axis=1)}.')
print(f'  You should know what should be :)')
# Out:
# Your z activation (class probabilities) is
# [[0.219 0.2   0.191 0.219 0.171]
#  [0.208 0.204 0.201 0.205 0.183]
#  [0.208 0.202 0.202 0.205 0.183]]
# The correct z activation (class probabilities) is
# [[0.219 0.2   0.191 0.219 0.171]
#  [0.208 0.204 0.201 0.205 0.183]
#  [0.208 0.202 0.202 0.205 0.183]]
# The sums across rows (for each data sample) are [1. 1. 1.].
#   You should know what should be :)

# %% [markdown]
# Test the `forward` method, focusing on loss

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y)
correct_loss = 1.564402690536365

print(f'Your average loss is\n{loss}')
print(f'The correct average loss is approx\n{correct_loss}')
# Out:
# Your average loss is
# 1.564402690536365
# The correct average loss is approx
# 1.564402690536365

# %% [markdown]
# Test the `forward` method, focusing on regularization

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y, reg=1000)
correct_loss = 5.257207314928798

print(f'Your regularized average loss is\n{loss}')
print(f'The correct regularized average loss is approx\n{correct_loss}')
# Out:
# Your regularized average loss is
# 5.257207314928799
# The correct regularized average loss is approx
# 5.257207314928798

# %% [markdown]
# Test the `backward` method

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y, reg=0.5)
grads = net.backward(test_x, test_y, y_in, y_act ,z_in, z_act, reg=0.5)

print('Your gradient for y_wts is\n', grads[0])
print('Your gradient for y_b is\n', grads[1])
print('Your gradient for z_wts is\n', grads[2])
print('Your gradient for z_b is\n', grads[3])
# Out:
# Your gradient for y_wts is
#  [[-0.476  0.057 -0.458 -0.115  0.03  -0.005  0.005]
#  [-0.002  0.014 -0.046 -0.162  0.004  0.004  0.001]
#  [-0.088  0.038 -0.166 -0.325 -0.001 -0.004 -0.013]
#  [-0.331  0.067 -0.398 -0.332  0.001  0.    -0.001]
#  [-0.318  0.089 -0.465 -0.615 -0.001 -0.01  -0.002]
#  [-0.315 -0.036 -0.036  0.806  0.029 -0.005 -0.007]]
# Your gradient for y_b is
#  [-0.005  0.    -0.004 -0.     0.     0.     0.   ]
# Your gradient for z_wts is
#  [[-2.879  0.933  0.131  0.987  0.816]
#  [-1.69   0.669 -0.261  0.699  0.584]
#  [-0.374  0.278 -0.45   0.284  0.242]
#  [-3.221  1.041  0.154  1.111  0.904]
#  [ 0.024  0.027 -0.091  0.029  0.015]
#  [ 0.002 -0.003 -0.004 -0.003 -0.002]
#  [ 0.    -0.006  0.005  0.002 -0.008]]
# Your gradient for z_b is
#  [-0.455  0.202 -0.135  0.209  0.179]

# %% [markdown]
# The correct gradients are:
#
# `
# Your gradient for y_wts is
#  [[-0.476  0.057 -0.458 -0.115  0.03  -0.005  0.005]
#  [-0.002  0.014 -0.046 -0.162  0.004  0.004  0.001]
#  [-0.088  0.038 -0.166 -0.325 -0.001 -0.004 -0.013]
#  [-0.331  0.067 -0.398 -0.332  0.001  0.    -0.001]
#  [-0.318  0.089 -0.465 -0.615 -0.001 -0.01  -0.002]
#  [-0.315 -0.036 -0.036  0.806  0.029 -0.005 -0.007]]
# Your gradient for y_b is
#  [-0.005  0.    -0.004 -0.     0.     0.     0.   ]
# Your gradient for z_wts is
#  [[-2.879  0.933  0.131  0.987  0.816]
#  [-1.69   0.669 -0.261  0.699  0.584]
#  [-0.374  0.278 -0.45   0.284  0.242]
#  [-3.221  1.041  0.154  1.111  0.904]
#  [ 0.024  0.027 -0.091  0.029  0.015]
#  [ 0.002 -0.003 -0.004 -0.003 -0.002]
#  [ 0.    -0.006  0.005  0.002 -0.008]]
# Your gradient for z_b is
#  [-0.455  0.202 -0.135  0.209  0.179]
# `

# %% [markdown]
# Test loss over epoch.
#
# The below code should generate a curve that rapidly drops to 0 (there might be fluctuations and it might not be monotonic and that's ok)

# %%
net = MLP(num_features, num_hidden_units, num_classes)
loss, acc_t, acc_v = net.fit(test_x, test_y, test_x, test_y, reg=0, lr=0.001, mini_batch_sz=3, n_epochs=30)

plt.plot(loss)
plt.xlabel('Iteration')
plt.ylabel('Avg cross-entropy Loss')
plt.show()
# Out:
# Starting to train network...There will be 30 epochs and 30 iterations total, 1 iter/epoch.
#   Completed iter 0/30. Training loss: 3.78.
# Finished training!

# %% [markdown]
# ### c. Test MLP with Circle in Square dataset

# %% [markdown]
# First test case where training data = test data.
#
# You should see a nice drop and plateau in loss (after a bunch of print outs).

# %%
# train = test
hidden_size = 50
net = MLP(cis_train_x.shape[1], hidden_size, 2)
loss, acc_t, acc_v = net.fit(cis_test_x, cis_test_y, cis_val_x, cis_val_y, reg=.01, lr=0.01, mini_batch_sz=100, n_epochs=700)

plt.plot(loss)
plt.xlabel('Iteration')
plt.ylabel('Avg cross-entropy Loss')
plt.show()
# Out:
# Starting to train network...There will be 700 epochs and 70000 iterations total, 100 iter/epoch.
#   Completed iter 0/70000. Training loss: 0.71.
#   Completed iter 100/70000. Training loss: 0.70.
#   Completed iter 200/70000. Training loss: 0.70.
#   Completed iter 300/70000. Training loss: 0.70.
#   Completed iter 400/70000. Training loss: 0.70.
#   Completed iter 500/70000. Training loss: 0.70.
#   Completed iter 600/70000. Training loss: 0.70.
#   Completed iter 700/70000. Training loss: 0.70.
#   Completed iter 800/70000. Training loss: 0.70.
#   Completed iter 900/70000. Training loss: 0.70.
#   Completed iter 1000/70000. Training loss: 0.70.
#   Completed iter 13200/70000. Training loss: 0.62.
#   Completed iter 13300/70000. Training loss: 0.64.
#   Completed iter 13400/70000. Training loss: 0.61.
#   Completed iter 13500/70000. Training loss: 0.62.
#   Completed iter 13600/70000. Training loss: 0.62.
#   Completed iter 13700/70000. Training loss: 0.61.
#   Completed iter 13800/70000. Training loss: 0.62.
#   Completed iter 13900/70000. Training loss: 0.62.
#   Completed iter 14000/70000. Training loss: 0.59.
#   Completed iter 14100/70000. Training loss: 0.62.
#   Completed iter 14200/70000. Training loss: 0.63.
#   Completed iter 14300/70000. Training loss: 0.63.
#   Completed iter 14400/70000. Training loss: 0.62.
#   Completed iter 14500/70000. Training loss: 0.60.
#   Completed iter 14600/70000. Training loss: 0.62.
#   Completed iter 14700/70000. Training loss: 0.63.
#   Completed iter 14800/70000. Training loss: 0.62.
#   Completed iter 14900/70000. Training loss: 0.62.
#   Completed iter 15000/70000. Training loss: 0.61.
#   Completed iter 15100/70000. Training loss: 0.59.
#   Completed iter 15200/70000. Training loss: 0.61.
#   Completed iter 15300/70000. Training loss: 0.59.
#   Completed iter 15400/70000. Training loss: 0.61.
#   Completed iter 15500/70000. Training loss: 0.60.
#   Completed iter 15600/70000. Training loss: 0.60.
#   Completed iter 15700/70000. Training loss: 0.61.
#   Completed iter 15800/70000. Training loss: 0.62.
#   Completed iter 15900/70000. Training loss: 0.60.
#   Completed iter 16000/70000. Training loss: 0.60.
#   Completed iter 16100/70000. Training loss: 0.60.
#   Completed iter 16200/70000. Training loss: 0.59.
#   Completed iter 16300/70000. Training loss: 0.61.
#   Completed iter 16400/70000. Training loss: 0.61.
#   Completed iter 16500/70000. Training loss: 0.61.
#   Completed iter 16600/70000. Training loss: 0.60.
#   Completed iter 16700/70000. Training loss: 0.60.
#   Completed iter 16800/70000. Training loss: 0.57.
#   Completed iter 16900/70000. Training loss: 0.61.
#   Completed iter 17000/70000. Training loss: 0.59.
#   Completed iter 17100/70000. Training loss: 0.59.
#   Completed iter 17200/70000. Training loss: 0.62.
#   Completed iter 17300/70000. Training loss: 0.59.
#   Completed iter 17400/70000. Training loss: 0.57.
#   Completed iter 17500/70000. Training loss: 0.60.
#   Completed iter 17600/70000. Training loss: 0.60.
#   Completed iter 17700/70000. Training loss: 0.58.
#   Completed iter 17800/70000. Training loss: 0.60.
#   Completed iter 17900/70000. Training loss: 0.60.
#   Completed iter 18000/70000. Training loss: 0.58.
#   Completed iter 18100/70000. Training loss: 0.57.
#   Completed iter 18200/70000. Training loss: 0.60.
#   Completed iter 18300/70000. Training loss: 0.59.
#   Completed iter 18400/70000. Training loss: 0.59.
#   Completed iter 18500/70000. Training loss: 0.59.
#   Completed iter 18600/70000. Training loss: 0.60.
#   Completed iter 18700/70000. Training loss: 0.61.
#   Completed iter 18800/70000. Training loss: 0.57.
#   Completed iter 18900/70000. Training loss: 0.59.
#   Completed iter 19000/70000. Training loss: 0.57.
#   Completed iter 19100/70000. Training loss: 0.59.
#   Completed iter 19200/70000. Training loss: 0.57.
#   Completed iter 68000/70000. Training loss: 0.55.
#   Completed iter 68100/70000. Training loss: 0.55.
#   Completed iter 68200/70000. Training loss: 0.56.
#   Completed iter 68300/70000. Training loss: 0.55.
#   Completed iter 68400/70000. Training loss: 0.55.
#   Completed iter 68500/70000. Training loss: 0.55.
#   Completed iter 68600/70000. Training loss: 0.53.
#   Completed iter 68700/70000. Training loss: 0.53.
#   Completed iter 68800/70000. Training loss: 0.56.
#   Completed iter 68900/70000. Training loss: 0.53.
#   Completed iter 69000/70000. Training loss: 0.52.
#   Completed iter 69100/70000. Training loss: 0.56.
#   Completed iter 69200/70000. Training loss: 0.51.
#   Completed iter 69300/70000. Training loss: 0.53.
#   Completed iter 69400/70000. Training loss: 0.59.
#   Completed iter 69500/70000. Training loss: 0.53.
#   Completed iter 69600/70000. Training loss: 0.52.
#   Completed iter 69700/70000. Training loss: 0.55.
#   Completed iter 69800/70000. Training loss: 0.54.
#   Completed iter 69900/70000. Training loss: 0.56.
# Finished training!

# %% [markdown]
# **TODO**: Run the below cell after training and generate the CIS plot. You should see a well-defined circle inside a square region.

# %%
cis_test_y_pred = net.predict(cis_test_x)
plt.scatter(cis_test_x[:,0], cis_test_x[:,1], c=cis_test_y_pred)
plt.axis('equal')
plt.show()

# %% [markdown]
# **Second test case where training data != test data:** You should see a jagged polygon approximation to a circle inside a square region.

# %%
# train != test
net = MLP(cis_train_x.shape[1], hidden_size, 2)
loss, acc_t, acc_v = net.fit(cis_train_x, cis_train_y, cis_val_x, cis_val_y, reg=0, lr=0.1, mini_batch_sz=len(cis_train_x), n_epochs=10000)

plt.plot(loss)
plt.xlabel('Iteration')
plt.ylabel('Avg cross-entropy Loss')
plt.show()
# Out:
# Starting to train network...There will be 10000 epochs and 10000 iterations total, 1 iter/epoch.
#   Completed iter 0/10000. Training loss: 0.70.
#   Completed iter 100/10000. Training loss: 0.69.
#   Completed iter 200/10000. Training loss: 0.70.
#   Completed iter 300/10000. Training loss: 0.65.
#   Completed iter 400/10000. Training loss: 0.66.
#   Completed iter 500/10000. Training loss: 0.64.
#   Completed iter 600/10000. Training loss: 0.60.
#   Completed iter 700/10000. Training loss: 0.60.
#   Completed iter 800/10000. Training loss: 0.59.
#   Completed iter 900/10000. Training loss: 0.54.
#   Completed iter 1000/10000. Training loss: 0.55.
#   Completed iter 1100/10000. Training loss: 0.47.
#   Completed iter 1200/10000. Training loss: 0.41.
#   Completed iter 1300/10000. Training loss: 0.42.
#   Completed iter 1400/10000. Training loss: 0.41.
#   Completed iter 1500/10000. Training loss: 0.38.
#   Completed iter 1600/10000. Training loss: 0.41.
#   Completed iter 1700/10000. Training loss: 0.29.
#   Completed iter 1800/10000. Training loss: 0.33.
#   Completed iter 1900/10000. Training loss: 0.24.
#   Completed iter 2000/10000. Training loss: 0.20.
#   Completed iter 2100/10000. Training loss: 0.24.
#   Completed iter 2200/10000. Training loss: 0.18.
#   Completed iter 2300/10000. Training loss: 0.19.
#   Completed iter 2400/10000. Training loss: 0.17.
#   Completed iter 2500/10000. Training loss: 0.16.
#   Completed iter 2600/10000. Training loss: 0.15.
#   Completed iter 2700/10000. Training loss: 0.16.
#   Completed iter 2800/10000. Training loss: 0.15.
#   Completed iter 2900/10000. Training loss: 0.12.
#   Completed iter 3000/10000. Training loss: 0.09.
#   Completed iter 3100/10000. Training loss: 0.13.
#   Completed iter 3200/10000. Training loss: 0.10.
#   Completed iter 3300/10000. Training loss: 0.11.
#   Completed iter 3400/10000. Training loss: 0.11.
#   Completed iter 3500/10000. Training loss: 0.10.
#   Completed iter 3600/10000. Training loss: 0.12.
#   Completed iter 3700/10000. Training loss: 0.08.
#   Completed iter 3800/10000. Training loss: 0.06.
#   Completed iter 3900/10000. Training loss: 0.08.
#   Completed iter 4000/10000. Training loss: 0.08.
#   Completed iter 4100/10000. Training loss: 0.07.
#   Completed iter 4200/10000. Training loss: 0.06.
#   Completed iter 4300/10000. Training loss: 0.07.
#   Completed iter 4400/10000. Training loss: 0.06.
#   Completed iter 4500/10000. Training loss: 0.05.
#   Completed iter 4600/10000. Training loss: 0.06.
#   Completed iter 4700/10000. Training loss: 0.05.
#   Completed iter 4800/10000. Training loss: 0.05.
#   Completed iter 4900/10000. Training loss: 0.06.
#   Completed iter 5000/10000. Training loss: 0.05.
#   Completed iter 5100/10000. Training loss: 0.07.
#   Completed iter 5200/10000. Training loss: 0.04.
#   Completed iter 5300/10000. Training loss: 0.05.
#   Completed iter 5400/10000. Training loss: 0.05.
#   Completed iter 5500/10000. Training loss: 0.04.
#   Completed iter 5600/10000. Training loss: 0.03.
#   Completed iter 5700/10000. Training loss: 0.03.
#   Completed iter 5800/10000. Training loss: 0.03.
#   Completed iter 5900/10000. Training loss: 0.02.
#   Completed iter 6000/10000. Training loss: 0.04.
#   Completed iter 6100/10000. Training loss: 0.04.
#   Completed iter 6200/10000. Training loss: 0.03.
#   Completed iter 6300/10000. Training loss: 0.03.
#   Completed iter 6400/10000. Training loss: 0.03.
#   Completed iter 6500/10000. Training loss: 0.02.
#   Completed iter 6600/10000. Training loss: 0.05.
#   Completed iter 6700/10000. Training loss: 0.03.
#   Completed iter 6800/10000. Training loss: 0.05.
#   Completed iter 6900/10000. Training loss: 0.06.
#   Completed iter 7000/10000. Training loss: 0.03.
#   Completed iter 7100/10000. Training loss: 0.04.
#   Completed iter 7200/10000. Training loss: 0.02.
#   Completed iter 7300/10000. Training loss: 0.04.
#   Completed iter 7400/10000. Training loss: 0.02.
#   Completed iter 7500/10000. Training loss: 0.03.
#   Completed iter 7600/10000. Training loss: 0.03.
#   Completed iter 7700/10000. Training loss: 0.01.
#   Completed iter 7800/10000. Training loss: 0.03.
#   Completed iter 7900/10000. Training loss: 0.04.
#   Completed iter 8000/10000. Training loss: 0.03.
#   Completed iter 8100/10000. Training loss: 0.03.
#   Completed iter 8200/10000. Training loss: 0.02.
#   Completed iter 8300/10000. Training loss: 0.02.
#   Completed iter 8400/10000. Training loss: 0.03.
#   Completed iter 8500/10000. Training loss: 0.03.
#   Completed iter 8600/10000. Training loss: 0.03.
#   Completed iter 8700/10000. Training loss: 0.03.
#   Completed iter 8800/10000. Training loss: 0.02.
#   Completed iter 8900/10000. Training loss: 0.01.
#   Completed iter 9000/10000. Training loss: 0.03.
#   Completed iter 9100/10000. Training loss: 0.01.
#   Completed iter 9200/10000. Training loss: 0.02.
#   Completed iter 9300/10000. Training loss: 0.03.
#   Completed iter 9400/10000. Training loss: 0.03.
#   Completed iter 9500/10000. Training loss: 0.02.
#   Completed iter 9600/10000. Training loss: 0.03.
#   Completed iter 9700/10000. Training loss: 0.03.
#   Completed iter 9800/10000. Training loss: 0.01.
#   Completed iter 9900/10000. Training loss: 0.02.
# Finished training!

# %% [markdown]
# **TODO**: Run the below cell after training and generate the CIS plot.

# %%
cis_test_y_pred = net.predict(cis_test_x)
plt.scatter(cis_test_x[:,0], cis_test_x[:,1], c=cis_test_y_pred)
plt.axis('equal')
plt.show()

# %% [markdown]
# **Question 5**: How do you interpret the circle-in-square results? Do you think the single-layer net (with softmax) can handle the CIS dataset? Why or why not? (You're invited to try it, maybe as an extension :)
#
# **Question 6**: Play with # hidden units, epochs, regularization strength on CIS training...how does each parameter affect the results?

# %% [markdown]
# 5. We can use how circular the result is to determine how good our model is. When we vary the hyperparameters, the circle is squished and reshaped. We don't think a single-layer net would work with the dataset because we don't think a single layer network is powerful enough to work on such a low sample size.
#
# 6. Decreasing number of hidden units made our circle less circular where as increasing the number of hidden units improved our circle. Decreasing our epochs had a negative affect where it didn't even resemble a circle. Increasing epochs led to our circle having some flat edges. When we made reg of 1, we got a super small loss and an empty grid. A reg of 0.01 gave us a square like image.

# %% [markdown]
# ### d. Train on STL-10 dataset, plot performance

# %% [markdown]
# Try training the MLP on the below set of hyperparameters

# %%
net = MLP(x_train.shape[1], 100, 10)
loss, acc_t, acc_v = net.fit(x_train, y_train, x_val, y_val,
                             lr=0.05, reg=0.01, mini_batch_sz=500, n_epochs=50, verbose=0)
plt.plot(loss)
plt.xlabel('Training iteration')
plt.ylabel('Avg loss (cross entropy)')
plt.title('STL-10 loss')
plt.show()
# Out:
# Starting to train network...There will be 50 epochs and 350 iterations total, 7 iter/epoch.

# %%
plt.plot(acc_t, label='Training accuracy')
plt.plot(acc_v, label='Validation accuracy')
plt.xlabel('Training iteration')
plt.ylabel('Avg loss (cross entropy)')
plt.title('STL-10 accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Question 7**: What do the above loss and training and validation accuracy curves suggest about the quality of the hyperparameters used during training?

# %% [markdown]
# 7. The loss curve is a straight negative line which means that our loss is steadily decreasing, but it also means that we should train the net more until we see the loss even out at some value. The accuracy also suggests that the quality of the hyperparamters

# %% [markdown]
# ### e. Optimize on STL-10 dataset, plot performance
#
# **TODO** Write code in the cell below to perform a grid search to find the combinations of
#
# - learning rate
# - regularization strength
# - number hidden units
# - mini-batch size
#
# that yields the highest STL-10 validation set accuracy.
#
# You should be able to achieve higher accuracy than in the single layer version of the softmax network.

# %%
best_val_acc = 0
best_lr = 0.001
best_reg = 1
best_hidden = 1
best_mini_batch_sz = 100
 
upper_lr = 0.01
lower_lr = 0.0001

upper_reg = 20
lower_reg = 0

upper_batch = x_train.shape[0]
lower_batch = 10

upper_hidden = 100
lower_hidden = 1

arr1 = np.zeros((6,6,6,6))
 

for i in range(6):
    for j in range(6):
        for k in range(6):
            for l in range(6):
                print("i",i)
                print("j",j)
                print("k", k)
                print("l",l)
                batch = int(lower_batch + (upper_batch-lower_batch)/5*i)
                reg = lower_reg + (upper_reg-lower_reg)/5*j
                lr = (lower_lr + (upper_lr-lower_lr)/5*k)
                hid = int(lower_hidden + (upper_hidden-lower_hidden)/5*l)

                bestNet = MLP(x_train.shape[1], hid, 10)
                loss, acc_t, acc_v = bestNet.fit(x_test, y_test, x_val, y_val,
                                 lr= lr, reg=reg, mini_batch_sz=batch, n_epochs=10, verbose=0)
#                 bestNet = MLP(x_train)
#                 best_loss = bestNet.fit(x_train, y_train, lr = lr , reg = reg, mini_batch_sz= batch, n_epochs=10, verbose=0)
#                 y_test_pred = bestNet.predict(x_val)
#                 test_acc = bestNet.accuracy(y_val, y_test_pred)
                #arr1[i,j,k,l] = acc_v[-1]    
                y_test_pred = bestNet.predict(x_train)
                test_acc = bestNet.accuracy(y_test, y_test_pred)
                y_val_pred = bestNet.predict(x_val)
                val_acc = bestNet.accuracy(y_val, y_val_pred)
                arr1[i,j,k,l] = val_acc
             
            
print(np.unravel_index(np.argmax(arr1), (6,6,6,6)))
# print(np.unravel_index(126, (6,6,6))) # we got np.argmax(arr1) = 126
# Out:
# i 0
# j 0
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 0
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 1
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 2
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 3
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 4
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 0
# j 5
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 500 iterations total, 50 iter/epoch.
# i 1
# j 0
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 0
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 1
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 2
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 3
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 4
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 1
# j 5
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 2
# j 0
# k 2
# l 0
# ...
# i 5
# j 1
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 1
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 1
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 1
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 1
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 2
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 3
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 4
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 0
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 1
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 2
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 3
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 4
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 0
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 1
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 2
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 3
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 4
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# i 5
# j 5
# k 5
# l 5
# Starting to train network...There will be 10 epochs and 10 iterations total, 1 iter/epoch.
# (0, 1, 1, 2)

# %%
print(np.unravel_index(np.argmax(arr1), (6,6,6,6)))
print(int(lower_batch + (upper_batch-lower_batch)/5*0))
print( lower_reg + (upper_reg-lower_reg)/5*1)
print(lower_lr + (upper_lr-lower_lr)/5*1)
print(int(lower_hidden + (upper_hidden-lower_hidden)/5*(2)))
# Out:
# (0, 1, 1, 2)
# 10
# 4.0
# 0.00208
# 40

# %% [markdown]
# **TODO**: Set the parameters below to the best ones found by your grid search.
# - Generate and include the Test STL-10 loss curve
# - Generate and include the training and validation accuracy curves in the second cell down.
#
# Adjust the number of training epochs as needed.

# %%
# Train the net with the bestparam settings
best_lr = 0.0001
best_reg = 0.001
best_hidden = 50
best_mini_batch_sz = 10

bestNet = MLP(x_train.shape[1], best_hidden, 10)
loss, acc_t, acc_v = bestNet.fit(x_test, y_test, x_val, y_val,
                                 lr=best_lr, reg=best_reg, mini_batch_sz=best_mini_batch_sz, n_epochs=500, verbose=1)
plt.plot(loss)
plt.xlabel('Training iteration')
plt.ylabel('Avg loss (cross entropy)')
plt.title('Test STL-10 data loss')
plt.show()
# Out:
# Starting to train network...There will be 500 epochs and 25000 iterations total, 50 iter/epoch.
#   Completed iter 0/25000. Training loss: 3.13.
#   Completed iter 100/25000. Training loss: 3.34.
#   Completed iter 200/25000. Training loss: 3.53.
#   Completed iter 300/25000. Training loss: 3.51.
#   Completed iter 400/25000. Training loss: 3.20.
#   Completed iter 500/25000. Training loss: 3.25.
#   Completed iter 600/25000. Training loss: 3.44.
#   Completed iter 700/25000. Training loss: 3.23.
#   Completed iter 800/25000. Training loss: 3.20.
#   Completed iter 900/25000. Training loss: 3.44.
#   Completed iter 1000/25000. Training loss: 3.38.
#   Completed iter 1100/25000. Training loss: 3.32.
#   Completed iter 1200/25000. Training loss: 3.17.
#   Completed iter 1300/25000. Training loss: 3.03.
#   Completed iter 1400/25000. Training loss: 3.10.
#   Completed iter 1500/25000. Training loss: 2.97.
#   Completed iter 1600/25000. Training loss: 3.01.
#   Completed iter 1700/25000. Training loss: 3.06.
#   Completed iter 1800/25000. Training loss: 3.31.
#   Completed iter 1900/25000. Training loss: 3.38.
#   Completed iter 2000/25000. Training loss: 2.98.
#   Completed iter 2100/25000. Training loss: 2.95.
#   Completed iter 2200/25000. Training loss: 2.94.
#   Completed iter 2300/25000. Training loss: 3.04.
#   Completed iter 2400/25000. Training loss: 3.11.
#   Completed iter 2500/25000. Training loss: 3.17.
#   Completed iter 2600/25000. Training loss: 3.26.
#   Completed iter 2700/25000. Training loss: 3.45.
#   Completed iter 2800/25000. Training loss: 3.09.
#   Completed iter 2900/25000. Training loss: 3.23.
#   Completed iter 3000/25000. Training loss: 2.82.
#   Completed iter 3100/25000. Training loss: 3.06.
#   Completed iter 3200/25000. Training loss: 3.13.
#   Completed iter 3300/25000. Training loss: 2.87.
#   Completed iter 3400/25000. Training loss: 2.99.
#   Completed iter 3500/25000. Training loss: 3.17.
#   Completed iter 3600/25000. Training loss: 3.03.
#   Completed iter 3700/25000. Training loss: 2.89.
#   Completed iter 3800/25000. Training loss: 3.02.
#   Completed iter 3900/25000. Training loss: 3.43.
#   Completed iter 4000/25000. Training loss: 3.28.
#   Completed iter 4100/25000. Training loss: 3.05.
#   Completed iter 4200/25000. Training loss: 3.13.
#   Completed iter 4300/25000. Training loss: 2.98.
#   Completed iter 4400/25000. Training loss: 3.10.
#   Completed iter 4500/25000. Training loss: 2.98.
#   Completed iter 4600/25000. Training loss: 3.10.
#   Completed iter 4700/25000. Training loss: 3.08.
#   Completed iter 4800/25000. Training loss: 3.33.
#   Completed iter 4900/25000. Training loss: 2.85.
#   Completed iter 5000/25000. Training loss: 3.20.
#   Completed iter 5100/25000. Training loss: 3.07.
#   Completed iter 5200/25000. Training loss: 3.06.
#   Completed iter 5300/25000. Training loss: 3.14.
#   Completed iter 5400/25000. Training loss: 3.01.
#   Completed iter 5500/25000. Training loss: 3.02.
#   Completed iter 5600/25000. Training loss: 2.91.
#   Completed iter 5700/25000. Training loss: 3.04.
#   Completed iter 5800/25000. Training loss: 3.01.
#   Completed iter 5900/25000. Training loss: 3.09.
#   Completed iter 6000/25000. Training loss: 3.22.
#   Completed iter 6100/25000. Training loss: 2.65.
#   Completed iter 6200/25000. Training loss: 2.92.
#   Completed iter 6300/25000. Training loss: 3.03.
#   Completed iter 6400/25000. Training loss: 3.09.
#   Completed iter 6500/25000. Training loss: 2.76.
#   Completed iter 6600/25000. Training loss: 3.04.
#   Completed iter 6700/25000. Training loss: 3.07.
#   Completed iter 6800/25000. Training loss: 3.30.
#   Completed iter 6900/25000. Training loss: 2.83.
#   Completed iter 7000/25000. Training loss: 2.82.
#   Completed iter 7100/25000. Training loss: 2.89.
#   Completed iter 7200/25000. Training loss: 2.84.
#   Completed iter 7300/25000. Training loss: 3.36.
#   Completed iter 7400/25000. Training loss: 3.21.
#   Completed iter 7500/25000. Training loss: 3.02.
#   Completed iter 7600/25000. Training loss: 2.77.
#   Completed iter 7700/25000. Training loss: 2.98.
#   Completed iter 7800/25000. Training loss: 3.27.
#   Completed iter 7900/25000. Training loss: 3.02.
#   Completed iter 8000/25000. Training loss: 3.22.
#   Completed iter 8100/25000. Training loss: 3.04.
#   Completed iter 8200/25000. Training loss: 2.81.
#   Completed iter 8300/25000. Training loss: 2.91.
#   Completed iter 8400/25000. Training loss: 2.82.
#   Completed iter 8500/25000. Training loss: 3.19.
#   Completed iter 8600/25000. Training loss: 3.13.
#   Completed iter 8700/25000. Training loss: 3.06.
#   Completed iter 8800/25000. Training loss: 2.87.
#   Completed iter 8900/25000. Training loss: 2.85.
#   Completed iter 9000/25000. Training loss: 2.79.
#   Completed iter 9100/25000. Training loss: 3.09.
#   Completed iter 9200/25000. Training loss: 3.00.
#   Completed iter 9300/25000. Training loss: 2.94.
#   Completed iter 9400/25000. Training loss: 2.76.
#   Completed iter 9500/25000. Training loss: 2.93.
#   Completed iter 9600/25000. Training loss: 2.95.
#   Completed iter 9700/25000. Training loss: 3.06.
#   Completed iter 9800/25000. Training loss: 2.94.
#   Completed iter 9900/25000. Training loss: 3.16.
#   Completed iter 10000/25000. Training loss: 3.14.
#   Completed iter 10100/25000. Training loss: 3.00.
#   Completed iter 10200/25000. Training loss: 2.83.
#   Completed iter 10300/25000. Training loss: 2.69.
#   Completed iter 10400/25000. Training loss: 3.12.
#   Completed iter 10500/25000. Training loss: 2.75.
#   Completed iter 10600/25000. Training loss: 3.00.
#   Completed iter 10700/25000. Training loss: 2.80.
#   Completed iter 10800/25000. Training loss: 2.74.
#   Completed iter 10900/25000. Training loss: 2.90.
#   Completed iter 11000/25000. Training loss: 2.81.
#   Completed iter 11100/25000. Training loss: 2.86.
#   Completed iter 11200/25000. Training loss: 2.95.
#   Completed iter 11300/25000. Training loss: 3.03.
#   Completed iter 11400/25000. Training loss: 3.29.
#   Completed iter 11500/25000. Training loss: 3.04.
#   Completed iter 11600/25000. Training loss: 2.85.
#   Completed iter 11700/25000. Training loss: 2.76.
#   Completed iter 11800/25000. Training loss: 2.74.
#   Completed iter 11900/25000. Training loss: 3.17.
#   Completed iter 12000/25000. Training loss: 2.71.
#   Completed iter 12100/25000. Training loss: 2.80.
#   Completed iter 12200/25000. Training loss: 3.00.
#   Completed iter 12300/25000. Training loss: 2.80.
#   Completed iter 12400/25000. Training loss: 2.74.
#   Completed iter 12500/25000. Training loss: 2.87.
#   Completed iter 12600/25000. Training loss: 2.88.
#   Completed iter 12700/25000. Training loss: 2.96.
#   Completed iter 12800/25000. Training loss: 3.02.
#   Completed iter 12900/25000. Training loss: 2.86.
#   Completed iter 13000/25000. Training loss: 2.88.
#   Completed iter 13100/25000. Training loss: 2.91.
#   Completed iter 13200/25000. Training loss: 2.89.
#   Completed iter 13300/25000. Training loss: 2.77.
#   Completed iter 13400/25000. Training loss: 3.17.
#   Completed iter 13500/25000. Training loss: 2.77.
#   Completed iter 13600/25000. Training loss: 2.79.
#   Completed iter 13700/25000. Training loss: 2.61.
#   Completed iter 13800/25000. Training loss: 2.83.
#   Completed iter 13900/25000. Training loss: 3.08.
#   Completed iter 14000/25000. Training loss: 2.80.
#   Completed iter 14100/25000. Training loss: 3.03.
#   Completed iter 14200/25000. Training loss: 2.86.
#   Completed iter 14300/25000. Training loss: 2.62.
#   Completed iter 14400/25000. Training loss: 2.88.
#   Completed iter 14500/25000. Training loss: 2.86.
#   Completed iter 14600/25000. Training loss: 3.08.
#   Completed iter 14700/25000. Training loss: 2.91.
#   Completed iter 14800/25000. Training loss: 2.73.
#   Completed iter 14900/25000. Training loss: 2.95.
#   Completed iter 15000/25000. Training loss: 2.91.
#   Completed iter 15100/25000. Training loss: 2.81.
#   Completed iter 15200/25000. Training loss: 2.59.
#   Completed iter 15300/25000. Training loss: 2.53.
#   Completed iter 15400/25000. Training loss: 2.72.
#   Completed iter 15500/25000. Training loss: 2.90.
#   Completed iter 15600/25000. Training loss: 2.40.
#   Completed iter 15700/25000. Training loss: 3.08.
#   Completed iter 15800/25000. Training loss: 2.91.
#   Completed iter 15900/25000. Training loss: 2.90.
#   Completed iter 16000/25000. Training loss: 2.87.
#   Completed iter 16100/25000. Training loss: 2.70.
#   Completed iter 16200/25000. Training loss: 2.59.
#   Completed iter 16300/25000. Training loss: 2.88.
#   Completed iter 16400/25000. Training loss: 2.60.
#   Completed iter 16500/25000. Training loss: 2.76.
#   Completed iter 16600/25000. Training loss: 2.79.
#   Completed iter 16700/25000. Training loss: 2.77.
#   Completed iter 16800/25000. Training loss: 2.77.
#   Completed iter 16900/25000. Training loss: 3.06.
#   Completed iter 17000/25000. Training loss: 2.68.
#   Completed iter 17100/25000. Training loss: 2.67.
#   Completed iter 17200/25000. Training loss: 2.52.
#   Completed iter 17300/25000. Training loss: 2.68.
#   Completed iter 17400/25000. Training loss: 3.19.
#   Completed iter 17500/25000. Training loss: 2.71.
#   Completed iter 17600/25000. Training loss: 2.82.
#   Completed iter 17700/25000. Training loss: 2.93.
#   Completed iter 17800/25000. Training loss: 2.98.
#   Completed iter 17900/25000. Training loss: 2.70.
#   Completed iter 18000/25000. Training loss: 2.85.
#   Completed iter 18100/25000. Training loss: 2.75.
#   Completed iter 18200/25000. Training loss: 2.77.
#   Completed iter 18300/25000. Training loss: 2.96.
#   Completed iter 18400/25000. Training loss: 2.69.
#   Completed iter 18500/25000. Training loss: 2.53.
#   Completed iter 18600/25000. Training loss: 2.83.
#   Completed iter 18700/25000. Training loss: 2.85.
#   Completed iter 18800/25000. Training loss: 2.72.
#   Completed iter 18900/25000. Training loss: 2.77.
#   Completed iter 19000/25000. Training loss: 2.73.
#   Completed iter 19100/25000. Training loss: 2.81.
#   Completed iter 19200/25000. Training loss: 2.58.
#   Completed iter 19300/25000. Training loss: 3.02.
#   Completed iter 19400/25000. Training loss: 2.75.
#   Completed iter 19500/25000. Training loss: 2.92.
#   Completed iter 19600/25000. Training loss: 2.64.
#   Completed iter 19700/25000. Training loss: 2.74.
#   Completed iter 19800/25000. Training loss: 2.86.
#   Completed iter 19900/25000. Training loss: 2.47.
#   Completed iter 20000/25000. Training loss: 2.70.
#   Completed iter 20100/25000. Training loss: 2.97.
#   Completed iter 20200/25000. Training loss: 2.48.
#   Completed iter 20300/25000. Training loss: 2.74.
#   Completed iter 20400/25000. Training loss: 2.72.
#   Completed iter 20500/25000. Training loss: 2.85.
#   Completed iter 20600/25000. Training loss: 2.75.
#   Completed iter 20700/25000. Training loss: 2.78.
#   Completed iter 20800/25000. Training loss: 2.97.
#   Completed iter 20900/25000. Training loss: 2.86.
#   Completed iter 21000/25000. Training loss: 2.87.
#   Completed iter 21100/25000. Training loss: 2.70.
#   Completed iter 21200/25000. Training loss: 2.76.
#   Completed iter 21300/25000. Training loss: 2.70.
#   Completed iter 21400/25000. Training loss: 2.65.
#   Completed iter 21500/25000. Training loss: 2.70.
#   Completed iter 21600/25000. Training loss: 2.72.
#   Completed iter 21700/25000. Training loss: 2.64.
#   Completed iter 21800/25000. Training loss: 2.63.
#   Completed iter 21900/25000. Training loss: 2.89.
#   Completed iter 22000/25000. Training loss: 2.87.
#   Completed iter 22100/25000. Training loss: 2.70.
#   Completed iter 22200/25000. Training loss: 2.52.
#   Completed iter 22300/25000. Training loss: 2.87.
#   Completed iter 22400/25000. Training loss: 2.94.
#   Completed iter 22500/25000. Training loss: 3.05.
#   Completed iter 22600/25000. Training loss: 2.83.
#   Completed iter 22700/25000. Training loss: 2.60.
#   Completed iter 22800/25000. Training loss: 2.69.
#   Completed iter 22900/25000. Training loss: 2.82.
#   Completed iter 23000/25000. Training loss: 2.73.
#   Completed iter 23100/25000. Training loss: 2.79.
#   Completed iter 23200/25000. Training loss: 2.85.
#   Completed iter 23300/25000. Training loss: 2.78.
#   Completed iter 23400/25000. Training loss: 2.29.
#   Completed iter 23500/25000. Training loss: 2.54.
#   Completed iter 23600/25000. Training loss: 2.72.
#   Completed iter 23700/25000. Training loss: 2.65.
#   Completed iter 23800/25000. Training loss: 2.85.
#   Completed iter 23900/25000. Training loss: 2.44.
#   Completed iter 24000/25000. Training loss: 2.97.
#   Completed iter 24100/25000. Training loss: 2.56.
#   Completed iter 24200/25000. Training loss: 2.65.
#   Completed iter 24300/25000. Training loss: 2.65.
#   Completed iter 24400/25000. Training loss: 2.73.
#   Completed iter 24500/25000. Training loss: 3.02.
#   Completed iter 24600/25000. Training loss: 2.92.
#   Completed iter 24700/25000. Training loss: 2.81.
#   Completed iter 24800/25000. Training loss: 2.60.
#   Completed iter 24900/25000. Training loss: 2.58.
# Finished training!

# %%
plt.plot(acc_t, label='Training accuracy')
plt.plot(acc_v, label='Validation accuracy')
plt.xlabel('Training iteration')
plt.ylabel('Avg loss (cross entropy)')
plt.title('Test STL-10 data accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### e. Visualize learned weights

# %% [markdown]
# **TODO**:
#
# - In the cell below, get the weights of your best net's hidden layer (Y), reshape/transpose them so that they are `(N, 32, 32, 3)`.
# - Run the `plot_weights` function to generate a grid visualization of them.

# %%
best_y_wts = bestNet.get_y_wts()
print(best_y_wts.shape)
best_y_wts = best_y_wts.reshape(50,32,32,3)
# Out:
# (3072, 50)

# %%
def plot_weights(wts):
    grid_sz = int(np.sqrt(len(wts)))
    plt.figure(figsize=(20,20))
    for x in range(grid_sz):
        for y in range(grid_sz):
            lin_ind = np.ravel_multi_index((x, y), dims=(grid_sz, grid_sz))
            plt.subplot(grid_sz, grid_sz, lin_ind+1)
            currImg = wts[lin_ind]
            low, high = np.min(currImg), np.max(currImg)
            currImg = 255*(currImg - low) / (high - low)
            currImg = currImg.astype('uint8')
            plt.imshow(currImg)
            plt.gca().axis('off')
    plt.show()

# %%
plot_weights(best_y_wts)

# %% [markdown]
# ## Extensions
#
# **Reminder**: Please do not integrate extensions into your base project so that it changes the expected behavior of core functions. It is better to duplicate the base project and add features from there.
#
# 1) Instead of computing the loss over a mini-batch, compute it over epochs instead. Compare and contrast the approaches. Be sure to include analysis figures.
#
# 2) Investigate how the single layer softmax network does with the CIS dataset. Explain and provide plots showing your results.
#
# 3) If you have time to spare (or want to throw more computing power at the STL-10 dataset), process through the SLP and MLP and tune hyperparameters with the dataset at its original resolution (96x96 images). Show images of your learned weights. Can you find a training sweet spot where the learned weight visualizations look particularly cool?
#
# 4) Implement the sigmoid classifer (same network structure, except use sigmoid for netact) with the cross-entropy loss by creating another subclass of `SingleLayerNet` and/or `MLP`. Compare and contrast results achieved by the softmax/cross-entropy network.
#
# 5) Explore the effects of batch gradient descent, stochastic gradient descent, and mini-batch gradient descent.
#
# 6) Obtain, preprocess, train, and evaluate the performance of `SingleLayerNet` and/or `MLP` on another dataset with comparable types of image features.

# %% [markdown]
# Extension descriptions can be found in softmax_layer_Extension
